# %%
# %matplotlib notebook
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn
import pickle
import random
import json
from sklearn.decomposition import PCA
import warnings
warnings.filterwarnings('ignore')
path = r"C:\Users\hexie\OneDrive\Desktop\Projects\SAMPLING_DESKTOP\Sampling_codes\olp\\"
savepath = r"C:\Users\hexie\OneDrive\Desktop\Projects\SAMPLING_DESKTOP\Sampling_codes\plots\\"

dom = np.load("domains.npy", allow_pickle=True)
types = np.load("types.npy", allow_pickle=True)


auc_aa = np.load("20auc_aa.npy", allow_pickle=True) 
auc_prob = np.load("20auc_prob.npy", allow_pickle=True)
auc_pa = np.load("20auc_pa.npy", allow_pickle=True)
auc_emb = np.load("20auc_emb.npy", allow_pickle=True)
auc_olp = np.load("20auc_olp.npy", allow_pickle=True)
auc_jc = np.load("20auc_jc.npy", allow_pickle=True)
auc_gae = np.load("20auc_gae.npy", allow_pickle=True)
auc_dcsbm = np.load("20auc_dcsbm.npy", allow_pickle=True)
auc_mod = np.load("20auc_mod.npy", allow_pickle=True)
auc_spec = np.load("20auc_spec.npy", allow_pickle=True)



auc_aa_1 = np.load("auc_aa_wonan.npy", allow_pickle=True)
auc_prob_1 = np.load("auc_prob_wonan.npy", allow_pickle=True)
auc_pa_1 = np.load("auc_pa_wonan.npy", allow_pickle=True)
auc_emb_1 = np.load("auc_emb_wonan.npy", allow_pickle=True)
auc_olp_1 = np.load("auc_olp_wonan.npy", allow_pickle=True)
auc_jc_1 = np.load("auc_jc_wonan.npy", allow_pickle=True)
auc_gae_1 = np.load("auc_gae_wonan.npy", allow_pickle=True)
auc_dcsbm_1 = np.load("auc_dcsbm_wonan.npy", allow_pickle=True)
auc_mod_1 = np.load("auc_modularity_wonan.npy", allow_pickle=True)
auc_spec_1 = np.load("auc_spectral_wonan.npy", allow_pickle=True)


sampling_methods = ['Random Node Sampler', 'Degree Based Sampler', 'Page Rank Based Sampler', 'Random Edge Sampler',
 'Random Node Edge Sampler', 'Hybrid Node Edge Sampler',
 'Random Edge Sampler With Induction', 'Diffusion Sampler',
 'Forest Fire Sampler',
 'Nonbacktracking Randomwalk Sampler', 'Loop Erased Randomwalk Sampler',
 'Randomwalk Sampler', 'Randomwalk With Restart Sampler','Metropolis Hastings Randomwalk Sampler', 
 'Circulated Neighbors Randomwalk Sampler', 'Breadth First Search Sampler',
 'Depth First Search Sampler', 'Randomwalk With Jump Sampler',
 'Random Node Neighbor Sampler', 'Shortest Path Sampler']


print(np.nanmean(mylist, axis =0))


auc_methods = ['aa', 'n2v_dot_prod', 'pa', 'n2v_edge_emb', 'jc', 'dcsbm', 'mod', 'spec', 'olp']

auc_methods = ["Adamic-Adar", "Node2Vec Dot Product", "Preferential Attachment", "Node2Vec Edge Embedding",
              "Jaccard Coefficient", "MDL-DCSBM", "Modularity", "Spectral Clustering", "Top-Stacking"]



Biological_index = [i for i, x in enumerate(dom) if x == "Biological"]
Economic_index = [i for i, x in enumerate(dom) if x == "Economic"]
Informational_index = [i for i, x in enumerate(dom) if x == "Informational"]
Social_index = [i for i, x in enumerate(dom) if x == "Social"]
Technological_index = [i for i, x in enumerate(dom) if x == "Technological"]
Transportation_index = [i for i, x in enumerate(dom) if x == "Transportation"]

# sampling_methods = ['RandomNodeSampler', 'DegreeBasedSampler', 'PageRankBasedSampler', 'RandomEdgeSampler',
#  'RandomNodeEdgeSampler', 'HybridNodeEdgeSampler',
#  'RandomEdgeSamplerWithInduction', 'DiffusionSampler',
#  'ForestFireSampler',
#  'NonBackTrackingRandomWalkSampler', 'LoopErasedRandomWalkSampler',
#  'RandomWalkSampler', 'RandomWalkWithRestartSampler','MetropolisHastingsRandomWalkSampler', 'CirculatedNeighborsRandomWalkSampler', 'BreadthFirstSearchSampler',
#  'DepthFirstSearchSampler', 'RandomWalkWithJumpSampler',
#  'RandomNodeNeighborSampler', 'ShortestPathSampler']

print(len(sampling_methods))
# Out:
# [0.74602266 0.72543714 0.70394304 0.68239289 0.83791317 0.73601017
#  0.7881002  0.74010478 0.7752723  0.71064917 0.69257255 0.70665342
#  0.66206164 0.81374063 0.68322325 0.7231822  0.66697307 0.8063119
#  0.75278702 0.76092227 0.72904484 0.78610823 0.77887981 0.74331218
#  0.73307844 0.72465186 0.7657589  0.73433292 0.71545232 0.68919524
#  0.69697286 0.70253088 0.70776404 0.73930347 0.7147611  0.68247164
#  0.7157217  0.72171206 0.71081585 0.67146527 0.71749588 0.72077478
#  0.71595313 0.71567425 0.69954635 0.68462071 0.6909391  0.67562652
#  0.72024778 0.71867809 0.67554405 0.74069245 0.6490583  0.69180952
#  0.81355581 0.84252846 0.86550048 0.665654   0.70540017 0.75718742
#  0.68103545 0.68787032 0.72304225 0.74546767 0.69571415 0.68879241
#  0.67253152 0.73126746 0.67692786 0.65197222 0.72370369 0.73228258
#  0.7218996  0.7184099  0.73841267 0.6827999  0.67451849 0.76086207
#  0.72010232 0.77855062 0.84701754 0.87421823 0.79638906 0.75449982
#  0.7145658  0.69001915 0.88405773 0.9124784  0.84301779 0.88339409
#  0.8937503  0.88265079 0.75647441 0.99633028 0.75626938 0.73069238
#  0.69149193 0.83668537 0.89961654 0.90670273 0.90582262 0.92202003
#  0.94550894 0.93761499 0.94245827 0.93385099 0.9405863  0.91893965
#  0.93166663 0.94349283 0.92898934 0.94618709 0.94873226 0.94666343
#  0.93534607 0.92920819 0.95007663 0.94049747 0.92021063 0.94089115
#  0.9509152  0.93800919 0.93477527 0.93846551 0.9430085  0.93331015
#  0.94223553 0.94312875 0.93344162 0.92806759 0.95746504 0.9537679
#  0.94077094 0.93872868 0.9327465  0.93626019 0.91546528 0.92809112
#  0.94443842 0.94131596 0.94039553 0.92175271 0.94537886 0.92825405
#  0.94980968 0.93753506 0.95242355 0.93981185 0.94792541 0.93419748
#  0.93312846 0.94246742 0.92768805 0.93777544 0.9244245  0.93670407
#  0.92350583 0.93262006 0.93375982 0.92351444 0.76902624 0.71118443
#  0.70393515 0.75389816 0.75880037 0.74865236 0.80984346 0.73970015
#  0.71666051 0.82798972 0.76661318 0.75383895 0.74397047 0.79947108
#  0.73103844 0.71708318 0.65799749 0.70057431 0.75528826 0.77275176
#  0.76113793 0.7458662  0.65943642 0.68075845 0.70742295 0.69053728
#  0.7237822  0.7875051  0.73017721 0.69588348 0.77905666 0.73135788
#  0.68883642 0.71606643 0.72976638 0.78130636 0.6990911  0.67546664
#  0.68973373 0.80900934 0.76015757 0.75356961 0.71989115 0.72193451
#  0.7834047  0.79778176 0.77437034 0.81813414 0.72085821 0.7111935
#  0.70777823 0.68975802 0.70962506 0.65800036 0.67679919 0.7055247
#  0.69694802 0.80877101 0.62168717 0.61569958 0.62484743 0.61145455
#  0.7221982  0.78171704 0.71399214 0.80221515 0.71924708 0.73786946
#  0.72453913 0.68965778 0.69918572 0.67851888 0.71866675 0.69882879
#  0.66867432 0.73186735 0.70503387 0.68972492 0.70796384 0.67456224
#  0.70851423 0.66474965 0.73635589 0.68206542 0.72058679 0.71560758
#  0.70563726 0.84436856 0.80064214 0.85866373]
# 20

# %%
dfs = []
for arr, method_name in zip([
    auc_aa_1,
    auc_prob_1,
    auc_pa_1,
    auc_emb_1,
    auc_jc_1,
    auc_dcsbm_1,
    auc_mod_1,
    auc_spec_1,
    auc_olp_1
], auc_methods):
    df = pd.DataFrame(arr, columns=sampling_methods)
    df["method"] = method_name
    df["domain"] = dom
    dfs.append(df)
df = pd.concat(dfs).dropna().reset_index()

# %%
# Out:
# 0        Adamic-Adar
# 1        Adamic-Adar
# 2        Adamic-Adar
# 3        Adamic-Adar
# 4        Adamic-Adar
#             ...
# 1814    Top-Stacking
# 1815    Top-Stacking
# 1816    Top-Stacking
# 1817    Top-Stacking
# 1818    Top-Stacking
# Name: method, Length: 1819, dtype: object

# %%
df.groupby(["domain", "method"])["Diffusion Sampler"].describe()
# Out:
#                                         count      mean       std       min  \
# domain         method
# Biological     Adamic-Adar               52.0  0.751285  0.141673  0.524370
#                Jaccard Coefficient       50.0  0.744955  0.141270  0.532978
#                MDL-DCSBM                101.0  0.810897  0.107149  0.507000
#                Modularity                99.0  0.693059  0.099137  0.520125
#                Node2Vec Dot Product      80.0  0.669138  0.112000  0.518181
#                Node2Vec Edge Embedding   98.0  0.696840  0.116692  0.538790
#                Preferential Attachment  102.0  0.761571  0.073055  0.511666
#                Spectral Clustering       97.0  0.818191  0.077467  0.639767
#                Top-Stacking             102.0  0.834375  0.085652  0.619600
# Economic       Adamic-Adar                8.0  0.810690  0.067066  0.678596
#                Jaccard Coefficient        7.0  0.775974  0.093172  0.616684
#                MDL-DCSBM                  9.0  0.740647  0.130664  0.591850
#                Modularity                 9.0  0.620406  0.096605  0.516025
#                Node2Vec Dot Product       7.0  0.607981  0.096995  0.527032
#                Node2Vec Edge Embedding    8.0  0.719016  0.117310  0.573574
#                Preferential Attachment    9.0  0.807340  0.080468  0.687520
#                Spectral Clustering        9.0  0.807874  0.070884  0.720267
#                Top-Stacking               5.0  0.817273  0.039937  0.756124
# Informational  Adamic-Adar               12.0  0.720729  0.101548  0.539577
#                Jaccard Coefficient       11.0  0.672193  0.100362  0.518669
#                MDL-DCSBM                 12.0  0.796800  0.107313  0.661325
#                Modularity                12.0  0.701744  0.084807  0.587225
#                Node2Vec Dot Product       8.0  0.626004  0.098871  0.518704
#                Node2Vec Edge Embedding   10.0  0.734278  0.093889  0.587662
#                Preferential Attachment   10.0  0.775200  0.063598  0.663037
#                Spectral Clustering       12.0  0.790547  0.044652  0.708600
#                Top-Stacking              10.0  0.792591  0.065601  0.649543
# Social         Adamic-Adar               73.0  0.959736  0.084439  0.607976
#                Jaccard Coefficient       73.0  0.954253  0.099078  0.521654
#                MDL-DCSBM                 72.0  0.908171  0.113044  0.549100
#                Modularity                69.0  0.900563  0.078444  0.574975
#                Node2Vec Dot Product      71.0  0.921172  0.078530  0.665317
#                Node2Vec Edge Embedding   74.0  0.950895  0.101285  0.574634
#                Preferential Attachment   73.0  0.750954  0.045047  0.656190
#                Spectral Clustering       69.0  0.923388  0.065680  0.673433
#                Top-Stacking              71.0  0.961246  0.071896  0.594461
# Technological  Adamic-Adar               12.0  0.688153  0.127576  0.533593
#                Jaccard Coefficient       12.0  0.664135  0.108518  0.534436
#                MDL-DCSBM                 15.0  0.662827  0.150530  0.500700
#                Modularity                24.0  0.743558  0.051300  0.647925
#                Node2Vec Dot Product      21.0  0.647150  0.067288  0.538532
#                Node2Vec Edge Embedding   25.0  0.742930  0.083545  0.593693
#                Preferential Attachment   20.0  0.717874  0.082795  0.577148
#                Spectral Clustering       23.0  0.739499  0.070902  0.630900
#                Top-Stacking              22.0  0.806189  0.072673  0.653844
# Transportation Adamic-Adar                5.0  0.674827  0.116979  0.561730
#                Jaccard Coefficient        5.0  0.675462  0.116778  0.561576
#                MDL-DCSBM                  3.0  0.549958  0.045920  0.514575
#                Modularity                 7.0  0.774629  0.039626  0.723375
#                Node2Vec Dot Product       7.0  0.711382  0.150145  0.554667
#                Node2Vec Edge Embedding    9.0  0.755748  0.041572  0.682180
#                Preferential Attachment    3.0  0.669893  0.044406  0.619400
#                Spectral Clustering        5.0  0.703740  0.045542  0.639833
#                Top-Stacking               7.0  0.830357  0.093572  0.733689
#
#                                              25%       50%       75%       max
# domain         method
# Biological     Adamic-Adar              0.625199  0.780916  0.877023  0.976695
#                Jaccard Coefficient      0.620832  0.765756  0.868449  0.979029
#                MDL-DCSBM                0.754800  0.842625  0.883950  0.999750
#                Modularity               0.608025  0.687150  0.764450  0.914375
#                Node2Vec Dot Product     0.585003  0.632818  0.747604  0.948033
#                Node2Vec Edge Embedding  0.605260  0.663913  0.774776  0.963731
#                Preferential Attachment  0.731648  0.771771  0.806220  0.917702
#                Spectral Clustering      0.772567  0.809567  0.894500  0.946267
#                Top-Stacking             0.769065  0.839736  0.888111  0.996242
# Economic       Adamic-Adar              0.784696  0.811460  0.855668  0.893187
#                Jaccard Coefficient      0.719274  0.817581  0.843720  0.871565
#                MDL-DCSBM                0.682900  0.694400  0.799250  0.975675
#                Modularity               0.542450  0.620800  0.641975  0.806225
#                Node2Vec Dot Product     0.556160  0.597007  0.600609  0.818290
#                Node2Vec Edge Embedding  0.613714  0.736815  0.780468  0.883147
#                Preferential Attachment  0.760540  0.787466  0.825047  0.962769
#                Spectral Clustering      0.757300  0.805600  0.830667  0.955867
#                Top-Stacking             0.810509  0.813438  0.851392  0.854902
# Informational  Adamic-Adar              0.662908  0.698205  0.816672  0.863164
#                Jaccard Coefficient      0.610462  0.633798  0.742555  0.840684
#                MDL-DCSBM                0.707306  0.776225  0.879587  0.961325
#                Modularity               0.626750  0.731563  0.763969  0.823350
#                Node2Vec Dot Product     0.565327  0.589248  0.683385  0.814083
#                Node2Vec Edge Embedding  0.693155  0.714848  0.808940  0.872832
#                Preferential Attachment  0.737145  0.770238  0.820754  0.881804
#                Spectral Clustering      0.767025  0.784450  0.839617  0.844433
#                Top-Stacking             0.759753  0.812790  0.830335  0.874216
# Social         Adamic-Adar              0.983191  0.991115  0.995590  0.999975
#                Jaccard Coefficient      0.981764  0.990485  0.994569  0.999248
#                MDL-DCSBM                0.943569  0.955462  0.960550  0.982325
#                Modularity               0.927300  0.931250  0.935475  0.946525
#                Node2Vec Dot Product     0.938615  0.948211  0.963030  0.981053
#                Node2Vec Edge Embedding  0.984729  0.991188  0.993404  0.995759
#                Preferential Attachment  0.713298  0.752266  0.780948  0.869702
#                Spectral Clustering      0.928000  0.946033  0.956467  0.970167
#                Top-Stacking             0.974536  0.989379  0.993728  1.000000
# Technological  Adamic-Adar              0.560315  0.697501  0.808653  0.842177
#                Jaccard Coefficient      0.560409  0.642194  0.778545  0.798153
#                MDL-DCSBM                0.531954  0.603650  0.809000  0.884075
#                Modularity               0.713625  0.745900  0.769062  0.824025
#                Node2Vec Dot Product     0.615184  0.630366  0.689410  0.764895
#                Node2Vec Edge Embedding  0.672771  0.750263  0.803482  0.878027
#                Preferential Attachment  0.670785  0.709253  0.777028  0.845116
#                Spectral Clustering      0.676550  0.739200  0.799750  0.859600
#                Top-Stacking             0.751560  0.823989  0.859711  0.903679
# Transportation Adamic-Adar              0.637141  0.639076  0.663572  0.872616
#                Jaccard Coefficient      0.637586  0.639633  0.666144  0.872371
#                MDL-DCSBM                0.524012  0.533450  0.567650  0.601850
#                Modularity               0.742600  0.781775  0.800312  0.831425
#                Node2Vec Dot Product     0.595982  0.637246  0.831135  0.933524
#                Node2Vec Edge Embedding  0.735023  0.750107  0.792017  0.817745
#                Preferential Attachment  0.653405  0.687411  0.695139  0.702868
#                Spectral Clustering      0.688500  0.699000  0.730867  0.760500
#                Top-Stacking             0.752411  0.817275  0.885766  0.985183

# %%
for col in sampling_methods:
    pos = 0
    fig = plt.figure(figsize=(15, 5))
    domain_ticks = []
    bps = []
    for domain in set(dom):
        for i, method in enumerate(auc_methods):
            color = palette[i]
            _df = df[
                (df.domain == domain)
                & (df.method == method)
            ].copy()
            bps.append(
                plt.boxplot(
                    _df[col], 
                    boxprops=dict(facecolor=color), 
                    medianprops=dict(linewidth=1.5), 
                    meanprops=dict(linewidth=1.5, linestyle="dotted"), 
                    positions=[pos], 
                    patch_artist=True, 
                    labels=[""], 
                    widths=[0.8], 
                    meanline=True, 
                    showmeans=True
                )
            )
            if i == 4:
                domain_ticks.append(pos)
            pos += 1
        pos += 5
    plt.xticks(domain_ticks, labels=set(dom))
    plt.legend([p["boxes"][0] for p in bps[:len(auc_methods)]], auc_methods, bbox_to_anchor=(1, 0.5), loc="center left")
    plt.title(col)
    plt.tight_layout()
    fig.savefig(col + " Boxplot.pdf")
# Out:
# <img src="data:image/png;base64,..." width="1500">
# <img src="data:image/png;base64,..." width="1500">
# <img src="data:image/png;base64,..." width="1500">
# <img src="data:image/png;base64,..." width="1500">
# <img src="data:image/png;base64,..." width="1500">
# <img src="data:image/png;base64,..." width="1500">
# <img src="data:image/png;base64,..." width="1500">
# <img src="data:image/png;base64,..." width="1500">
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_59096/3007968543.py in <module>
#      33     plt.title(col)
#      34     plt.tight_layout()
# ---> 35     fig.savefig(col + " Boxplot.pdf")
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\figure.py in savefig(self, fname, transparent, **kwargs)
#    3013                 patch.set_edgecolor('none')
#    3014
# -> 3015         self.canvas.print_figure(fname, **kwargs)
#    3016
#    3017         if transparent:
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2253                 # force the figure dpi to 72), so we need to set it again here.
#    2254                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2255                     result = print_method(
#    2256                         filename,
#    2257                         facecolor=facecolor,
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backend_bases.py in wrapper(*args, **kwargs)
#    1667             kwargs.pop(arg)
#    1668
# -> 1669         return func(*args, **kwargs)
#    1670
#    1671     return wrapper
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     429                          else deprecation_addendum,
#     430                 **kwargs)
# --> 431         return func(*inner_args, **inner_kwargs)
#     432
#     433     return wrapper
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_pdf.py in print_pdf(self, filename, dpi, bbox_inches_restore, metadata)
#    2716             file = filename._file
#    2717         else:
# -> 2718             file = PdfFile(filename, metadata=metadata)
#    2719         try:
#    2720             file.newPage(width, height)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_pdf.py in __init__(self, filename, metadata)
#     635         self.original_file_like = None
#     636         self.tell_base = 0
# --> 637         fh, opened = cbook.to_filehandle(filename, "wb", return_opened=True)
#     638         if not opened:
#     639             try:
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     460             fh = bz2.BZ2File(fname, flag)
#     461         else:
# --> 462             fh = open(fname, flag, encoding=encoding)
#     463         opened = True
#     464     elif hasattr(fname, 'seek'):
#
# PermissionError: [Errno 13] Permission denied: 'Diffusion Sampler Boxplot.pdf'

# %%
palette = seaborn.color_palette()
method_palette = dict(zip(auc_methods, palette))
method_

# %%
category = []
for idx in range(250):
    if idx in Biological_index:
        category.append("Biological")
    elif idx in Economic_index:
        category.append("Economic")
    elif idx in Informational_index:
        category.append("Informational")
    elif idx in Social_index:
        category.append("Social")
    elif idx in Technological_index:
        category.append("Technological")
    elif idx in Transportation_index:
        category.append("Transportation")

# %%
#df = pd.DataFrame(, columns=list('ABCD'))


mylist = np.hstack((auc_aa_1, auc_prob_1, auc_pa_1, auc_emb_1, auc_jc_1, auc_dcsbm_1, auc_mod_1, auc_spec_1, auc_olp_1))
mylist.shape
# Out:
# (250, 180)

# %%
data = [auc_aa_1, auc_prob_1, auc_pa_1, auc_emb_1, auc_jc_1, auc_dcsbm_1, auc_mod_1, auc_spec_1, auc_olp_1]

# %%
init = np.array([], dtype=float).reshape(250,0)
for samp_id, samp in enumerate(sampling_methods[0:1]): 
    print(samp_id)
    
    mylist = np.vstack((auc_aa_1[:,samp_id], auc_prob_1[:,samp_id], auc_pa_1[:,samp_id], auc_emb_1[:,samp_id], 
                        auc_jc_1[:,samp_id], auc_dcsbm_1[:,samp_id], auc_mod_1[:,samp_id], auc_spec_1[:,samp_id], 
                        auc_olp_1[:,samp_id]))
    val = mylist.transpose()
    dfs = pd.DataFrame(val, columns=auc_methods)
    df['cat'] = category
# Out:
# 0
# (250, 9)

# %%
df['E'] = [1, 2, 3, 1, 1, 4, 3, 2, 3, 1]
df
# Out:
#           A         B         C         D  E
# 0  0.354451  0.591309  0.868335  0.405060  1
# 1  0.406719  0.371420  0.021930  0.354740  2
# 2  0.247939  0.745068  0.971941  0.285874  3
# 3  0.344603  0.981175  0.865422  0.569946  1
# 4  0.050354  0.263939  0.393623  0.917181  1
# 5  0.983662  0.803403  0.760674  0.776957  4
# 6  0.702122  0.607456  0.915877  0.998184  3
# 7  0.496986  0.311845  0.604186  0.622880  2
# 8  0.175215  0.675579  0.845709  0.136127  3
# 9  0.391608  0.560457  0.952626  0.531644  1

# %%
ax = (
    df.set_index('E', append=True)  # set E as part of the index
      .stack()                      # pull A - D into rows 
      .to_frame()                   # convert to a dataframe
      .reset_index()                # make the index into reg. columns
      .rename(columns={'level_2': 'quantity', 0: 'value'})  # rename columns
      .drop('level_0', axis='columns')   # drop junk columns
      .pipe((seaborn.boxplot, 'data'), x='quantity', y='value', hue='E', hue_order=[1, 2])  
)
seaborn.despine(trim=True)
plt.legend(bbox_to_anchor=(1.3, 1), loc='upper right', title='Team')
